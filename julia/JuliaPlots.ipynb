# %% [markdown]
# <div style='background-image: url("../../share/images/header.svg") ; padding: 0px ; background-size: cover ; border-radius: 5px ; height: 250px'>
#     <div style="float: right ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.7) ; width: 50% ; height: 150px">
#         <div style="position: relative ; top: 50% ; transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.8) ; line-height: 100%">Plots en Julia</div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.5)">Ulises M. Alvarez</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# La librería, `Plots`, es una interface de visualización y una caja de herramientas. Nos permite usar el poder de muchas de las librerías de gráficos de Julia, *i.e. motores*, usando una sintaxis única.
#
# Como principales ventajas podemos destacar:
#
# * Dialecto de gráficos universal. No importa el motor de gráficos que estemos usando, `PyPlot, Gadfly, Plotly, PGFPlots,` etc, podemos usar un sólo dialecto para construir las gráficas.
#
# * Se puede cambiar el motor de gráficos con un sólo comando y no es necesario reescribir el código.
#
# * Es muy sencillo agregar capas, --anotaciones, leyendas, incluso gráficos adicionales superpuestos--, a un gráfico.

# %% [markdown]
# > **Para saber más:**
# > https://juliaplots.github.io/

# %% [markdown]
# # Prerrequisitos de sistema operativo
#
# En sistemas *Linux*, se necesita instalar el software:
# * libgtk-3-dev
# * libwandio-devel

# %% [markdown]
# # Instalación de librería
#
# ## Cero: Inicializar entorno de Julia

# %%
ENV["PYTHON"] = ""  # Declaramos la variable PYTHON nula, para reproducibilidad
Pkg.update()        # Actualizamos la biblioteca
# Out:
# INFO: Updating METADATA...
# INFO: Updating cache of UnicodePlots...
# INFO: Computing changes...
# INFO: Upgrading UnicodePlots: v0.2.3 => v0.2.4

# %% [markdown]
# ##  Función para facilitar y acelerar la instalación de las librerías

# %%
function p_it(p::String...)
    # Instala el paquete 'p'
    #
    # Args:
    #   p: el nombre completo del paquete::String
    #
    # Returns:
    #   Mensaje de error o notifica de la instalación vía Base.Pkg.add
    #
    ENV["PYTHON"]=""
    for i = 1:length(p)
        if !contains(==, Pkg.available(), p[i])
            println(p[i], ", no disponible.")
        else
            if !haskey(Pkg.installed(), p[i])
                Pkg.add(p[i])
            end
        end
     end
end
# Out:
# p_it (generic function with 1 method)

# %% [markdown]
# Para saber más sobre la función, lo invitamos a consultar la libreta "Paquetes en Julia II":
#
# * https://github.com/umalvarez/TallerJuR/blob/master/julia/PaquetesEnJulia-II.ipynb

# %% [markdown]
# ## Instalación de la librería y motores recomendados
#
# Una vez inicializado el entorno, procedemos a instalar la librería:
#
# * https://juliaplots.github.io/install/

# %%
p_it("Plots",
    "PlotlyJS",
    "PyPlot",
    "GR",
    "UnicodePlots",
    "PGFPlots")

# %% [markdown]
# ## Extensiones
#
# También instalaremos las extensiones recomendadas:

# %%
p_it("StatPlots", "PlotRecipes")

# %% [markdown]
# ## Auxiliares
#
# Para poder desplegar los gráficos generados con el motor, `PlotlyJS`, es importante instalar otros dos paquetes:

# %%
p_it("Rsvg", "Blink")

# %% [markdown]
# Una vez instalado, *Blink()*, es importante instalar su auxiliar:

# %%
using Blink                  # Cargamos el paquete
# Blink.AtomShell.install()  # Instalamos auxiliar. ¡Ejecutar sólo una vez!

# %% [markdown]
# **Referencia:** http://spencerlyon.com/PlotlyJS.jl/

# %% [markdown]
# **Nota:**
# > La instalación de librerías es un proceso que requiere de 10 a 20 minutos. El resultado variará de acuerdo a su sistema operativo y la velocidad de su conexión a Internet.

# %% [markdown]
# # Uso de `Plots`
#
# Una vez instaladas la librerías, podemos proceder a usar `Plots` con el motor de nuesta preferencia. Es importante señalar que:
#
# * Para generar estas notas usamos el motor, `GR`.
# * Para sesiones o documentos interactivos, *i.e. html,* se recomienda el motor `plotly()`.
# * Para poder exportar desde `Jupyter` o `IJulia`, es necesario especificar el formato de salida. Les recomendamos `SVG` o `PNG`. Ejemplo:
#
# ```julia
# plot(rand(10), fmt = :svg)
#
# ```
#
# > **URL:** https://juliaplots.github.io/output/

# %%
using Plots  # Cargamos librería
pyplot()     # Definimos motor, PyPlot
# Out:
# Plots.PyPlotBackend()

# %% [markdown]
# ## Gráfica simple de líneas
#
# Generaremos una gráfica de líneas. Usaremo el motor `PGFPlots` y `SVG` como formato de salida:

# %%
plot(Plots.fakedata(50, 5),  # las abcisas y las ordenadas, respectivamente
w   = 2,                     # Ancho de las líneas
fmt = :svg)                  # Opción para generar las notas
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 15.324646 273.485354
# L 426.555354 273.485354
# L 426.555354 2.834646
# L 15.324646 2.834646
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p7db17420c7)" d="M 90.856817 273.485354
# L 90.856817 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="m563aa4d616" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="90.856817" xlink:href="#m563aa4d616" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 10 -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#       </defs>
#       <g transform="translate(85.766817 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p7db17420c7)" d="M 174.781451 273.485354
# L 174.781451 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="174.781451" xlink:href="#m563aa4d616" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 20 -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#       </defs>
#       <g transform="translate(169.691451 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p7db17420c7)" d="M 258.706085 273.485354
# L 258.706085 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="258.706085" xlink:href="#m563aa4d616" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 30 -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53.90625 64.015625 53.90625 55.328125
# Q 53.90625 49.265625 50.4375 45.09375
# Q 46.96875 40.921875 40.578125 39.3125
# z
# " id="DejaVuSans-33"/>
#       </defs>
#       <g transform="translate(253.616085 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-33"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p7db17420c7)" d="M 342.63072 273.485354
# L 342.63072 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="342.63072" xlink:href="#m563aa4d616" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 40 -->
#       <defs>
#        <path d="M 37.796875 64.3125
# L 12.890625 25.390625
# L 37.796875 25.390625
# z
# M 35.203125 72.90625
# L 47.609375 72.90625
# L 47.609375 25.390625
# L 58.015625 25.390625
# L 58.015625 17.1875
# L 47.609375 17.1875
# L 47.609375 0
# L 37.796875 0
# L 37.796875 17.1875
# L 4.890625 17.1875
# L 4.890625 26.703125
# z
# " id="DejaVuSans-34"/>
#       </defs>
#       <g transform="translate(337.54072 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-34"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p7db17420c7)" d="M 426.555354 273.485354
# L 426.555354 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="426.555354" xlink:href="#m563aa4d616" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 50 -->
#       <defs>
#        <path d="M 10.796875 72.90625
# L 49.515625 72.90625
# L 49.515625 64.59375
# L 19.828125 64.59375
# L 19.828125 46.734375
# Q 21.96875 47.46875 24.109375 47.828125
# Q 26.265625 48.1875 28.421875 48.1875
# Q 40.625 48.1875 47.75 41.5
# Q 54.890625 34.8125 54.890625 23.390625
# Q 54.890625 11.625 47.5625 5.09375
# Q 40.234375 -1.421875 26.90625 -1.421875
# Q 22.3125 -1.421875 17.546875 -0.640625
# Q 12.796875 0.140625 7.71875 1.703125
# L 7.71875 11.625
# Q 12.109375 9.234375 16.796875 8.0625
# Q 21.484375 6.890625 26.703125 6.890625
# Q 35.15625 6.890625 40.078125 11.328125
# Q 45.015625 15.765625 45.015625 23.390625
# Q 45.015625 31 40.078125 35.4375
# Q 35.15625 39.890625 26.703125 39.890625
# Q 22.75 39.890625 18.8125 39

# %% [markdown]
# ## Histograma
#
# Histograma simple:

# %%
#plotly()               # ¡Pruebe diferentes motores!

histogram(randn(1000),  # histograma
fmt = :svg)             # Opción para generar las notas
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 17.574646 273.485354
# L 429.165354 273.485354
# L 429.165354 2.834646
# L 17.574646 2.834646
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p142d0f5870)" d="M 79.325778 273.485354
# L 79.325778 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="mfb789e9565" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="79.325778" xlink:href="#mfb789e9565" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- -2 -->
#       <defs>
#        <path d="M 4.890625 31.390625
# L 31.203125 31.390625
# L 31.203125 23.390625
# L 4.890625 23.390625
# z
# " id="DejaVuSans-2d"/>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#       </defs>
#       <g transform="translate(75.337653 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-2d"/>
#        <use x="36.083984" xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p142d0f5870)" d="M 204.581623 273.485354
# L 204.581623 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="204.581623" xlink:href="#mfb789e9565" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0 -->
#       <defs>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#       </defs>
#       <g transform="translate(202.036623 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p142d0f5870)" d="M 329.837469 273.485354
# L 329.837469 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="329.837469" xlink:href="#mfb789e9565" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 2 -->
#       <g transform="translate(327.292469 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <path clip-path="url(#p142d0f5870)" d="M 17.574646 273.485354
# L 429.165354 273.485354
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_8">
#       <defs>
#        <path d="M 0 0
# L -3.5 0
# " id="m6c7479d7c0" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="17.574646" xlink:href="#m6c7479d7c0" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 0 -->
#       <g transform="translate(5.484646 276.524729)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_9">
#       <path clip-path="url(#p142d0f5870)" d="M 17.574646 196.595948
# L 429.165354 196.595948
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="17.574646" xlink:href="#m6c7479d7c0" y="196.595948"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 25 -->
#       <defs>
#        <path d="M 10.796875 72.90625
# L 49.515625 72.90625
# L 49.515625 64.59375
# L 19.828125 64.59375
# L 19.828125 46.734375
# Q 21.96875 47.46875 24.109375 47.828125
# Q 26.265625 48.1875 28.421875 48.1875
# Q 40.625 48.1875 47.75 41.5
# Q 54.890625 34.8125 54.890625 23.390625
# Q 54.890625 11.625 47.5625 5.09375
# Q 40.234375 -1.421875 26.90625 -1.421875
# Q 22.3125 -1.421875 17.546875 -0.640625
# Q 12.796875 0.140625 7.71875 1.703125
# L 7.71875 11.625
# Q 12.109375 9.234375 16.796875 8.0625
# Q 21.484375 6.890625 26.703125 6.890625
# Q 35.15625 6.890625 40.078125 11.328125
# Q 45.015625 15.765625 45.015625 23.390625
# Q 45.015625 31 40.078125 35.4375
# Q 35.15625 39.890625 26.703125 39.890625
# Q 22.75 39.890625 18.8125 39.015625
# Q 14.890625 38.140625 10.796875 36.28125
# z
# " id="DejaVuSans-35"/>
#       </defs>
#       <g transform="translate(0.394646 199.635323)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_11">
#       <path clip-path="url(#p142d0f5870)" d="M 17.574646 119.706543
# L 429.165354 119.706543
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="17.574646" xlink:href="#m6c7479d7c0" y="119.706543"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 50 -->
#       <g transform="translate(0.394646 122.745918)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-35"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_4">
#      <g id="line2d_13">
#       <path clip-path="url(#p142d0f5870)" d="M 17.574646 42.817137
# L 429.165354 42.817137
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_14">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="17.574646" xlink:href="#m6c7479d7c0" y="42.817137"/>
#       </g>
#      </g>
#      <g id="text_7">
#       <!-- 75 -->
#       <defs>
#        <path d="M 8.203125 72.90625
# L 55.078125 72.90625
# L 55.078125 68.703125
# L 28.609375 0
# L 18.3125 0
# L 43.21875 64.59375
# L 8.203125 64.59375
# z
# " id="DejaVuSans-37"/>
#       </defs>
#       <g transform="translate(0.394646 45.856512)s

# %% [markdown]
# ## Colores
#
# Ahora, manipularemos colores, transparencia y agregaremos una capa de color superpuesta. Seguimos usando el motor `PyPlot`:

# %%
#plotly()              # ¡Pruebe diferentes motores!

y       = rand(100)    # Cien números aleatorios

plot(0:10:100,         # Iniciamos gráfica
rand(11,4),            # Subconjuntos aleatorios
lab     = "lines",     # Texto de la leyenda
w       = 3,           # Ancho de las líneas
palette = :grays,      # Paleta de color
fill    = (0, :auto),  # Área con color
α       = 0.4,         # Transparencia
fmt     = :svg)        # Opción para generar las notas
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 25.314646 273.485354
# L 423.990354 273.485354
# L 423.990354 2.834646
# L 25.314646 2.834646
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p32e28398c3)" d="M 25.314646 273.485354
# L 25.314646 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="m57fb718a07" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="25.314646" xlink:href="#m57fb718a07" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <defs>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#       </defs>
#       <g transform="translate(22.769646 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p32e28398c3)" d="M 105.049787 273.485354
# L 105.049787 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="105.049787" xlink:href="#m57fb718a07" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 20 -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#       </defs>
#       <g transform="translate(99.959787 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p32e28398c3)" d="M 184.784929 273.485354
# L 184.784929 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="184.784929" xlink:href="#m57fb718a07" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 40 -->
#       <defs>
#        <path d="M 37.796875 64.3125
# L 12.890625 25.390625
# L 37.796875 25.390625
# z
# M 35.203125 72.90625
# L 47.609375 72.90625
# L 47.609375 25.390625
# L 58.015625 25.390625
# L 58.015625 17.1875
# L 47.609375 17.1875
# L 47.609375 0
# L 37.796875 0
# L 37.796875 17.1875
# L 4.890625 17.1875
# L 4.890625 26.703125
# z
# " id="DejaVuSans-34"/>
#       </defs>
#       <g transform="translate(179.694929 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-34"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p32e28398c3)" d="M 264.520071 273.485354
# L 264.520071 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="264.520071" xlink:href="#m57fb718a07" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 60 -->
#       <defs>
#        <path d="M 33.015625 40.375
# Q 26.375 40.375 22.484375 35.828125
# Q 18.609375 31.296875 18.609375 23.390625
# Q 18.609375 15.53125 22.484375 10.953125
# Q 26.375 6.390625 33.015625 6.390625
# Q 39.65625 6.390625 43.53125 10.953125
# Q 47.40625 15.53125 47.40625 23.390625
# Q 47.40625 31.296875 43.53125 35.828125
# Q 39.65625 40.375 33.015625 40.375
# z
# M 52.59375 71.296875
# L 52.59375 62.3125
# Q 48.875 64.0625 45.09375 64.984375
# Q 41.3125 65.921875 37.59375 65.921875
# Q 27.828125 65.921875 22.671875 59.328125
# Q 17.53125 52.734375 16.796875 39.40625
# Q 19.671875 43.65625 24.015625 45.921875
# Q 28.375 48.1875 33.59375 48.1875
# Q 44.578125 48.1875 50.953125 41.515625
# Q 57.328125 34.859375 57.328125 23.390625
# Q 57.328125 12.15625 50.6875 5.359375
# Q 44.046875 -1.421875 33.015625 -1.421875
# Q 20.359375 -1.421875 13.671875 8.265625
# Q 6.984375 17.96875 6.984375 36.375
# Q 6.984375 53.65625 15.1875 63.9375
# Q 23.390625 74.21875 37.203125 74.21875
# Q 40.921875 74.21875 44.703125 73.484375
# Q 48.484375 72.75 52.59375 71.296875
# z
# " id="DejaVuSans-36"/>
#       </defs>
#       <g transform="translate(259.430071 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-36"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p32e28398c3)" d="M 344.255213 273.485354
# L 344.255213 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="344.255213" xlink:href="#m57fb718a07" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 80 -->
#       <defs>
#        <path d="M 31.78125 34.625
# Q 24.75 34.625 20.71875 30.859375
# Q 16.703125 27.09375 16.703125 20.515625
# Q 16.703125 13.921875 20.71875 10.15625
# Q 24.75 6.390625 31.78125 6.390625
# Q 38.8125 6.390625 42.859375 10.171875
# Q 46.921875 13.96875 46.921875 20.515625
# Q 46.921875 27.09375 42.890625 30.859375
# Q 38.875 34.625 31.78125 34.625
# z
# M 21.921875 38.8125
# Q 15.578125 40.375 12.03125 44.71875
# Q 8.5 49.078125 8.5 55.328125
# Q 8.5 64.0625 14.71875 69.140625
# Q 20.953125 74.21875 31.78125 74.21875
# Q 42.671875 74.21875 48.875 69.140625
# Q 55.078125 64.0625 55.078125 55.328125
# Q 55.078125 49.078125 51.53125 44.71875
# Q 48 40.375 41.703125 38.8125
# Q 48.828125 37.15625 52.796875 32.3125
# Q 56.78125 27.484375 56.78125 20.515625
# Q 56.78125 9.90625 50.3125 4.234375
# Q 43.84375 -1.421875 31.78125 -1.421875
# Q 19.734375 -1.421875 13.25 4.234375
# Q 6.78125 9.90625 6.78125 20.515625
# Q 6.78125 27.484375 10.78125 32.3125
# Q 14.796875 37.15625 21.921875 38.8125
# z
# M 18.3125 54.390625
# Q 18.3125 48.734375 21.84375 45.5625
# Q 25.390625 42.390625 31.78125 42.390625
# Q 38.140625

# %% [markdown]
# Para modificar la gráfica, color en esta caso, basta con agregar "`!`" al comando:

# %%
scatter!(y, 
        zcolor = abs(y - 0.5),
        m      = (:heat, 0.8, stroke(1, :green)),
        ms     = 10 * abs(y - 0.5) + 4,
        lab    = "grad",
        fmt    = :svg)  # Opción para generar las notas
# Out:
# WARNING: abs{T <: Number}(x::AbstractArray{T}) is deprecated, use abs.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  [2] abs(::Array{Float64,1}) at ./deprecated.jl:51
#  [3] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/uma/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [4] eventloop(::ZMQ.Socket) at /home/uma/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [5] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[11], in expression starting on line 1
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 20.184646 273.485354
# L 392.542441 273.485354
# L 392.542441 2.834646
# L 20.184646 2.834646
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pebc83bd87c)" d="M 30.723074 273.485354
# L 30.723074 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="mf9f654c1f0" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="30.723074" xlink:href="#mf9f654c1f0" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <defs>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#       </defs>
#       <g transform="translate(28.178074 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#pebc83bd87c)" d="M 206.363543 273.485354
# L 206.363543 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="206.363543" xlink:href="#mf9f654c1f0" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 50 -->
#       <defs>
#        <path d="M 10.796875 72.90625
# L 49.515625 72.90625
# L 49.515625 64.59375
# L 19.828125 64.59375
# L 19.828125 46.734375
# Q 21.96875 47.46875 24.109375 47.828125
# Q 26.265625 48.1875 28.421875 48.1875
# Q 40.625 48.1875 47.75 41.5
# Q 54.890625 34.8125 54.890625 23.390625
# Q 54.890625 11.625 47.5625 5.09375
# Q 40.234375 -1.421875 26.90625 -1.421875
# Q 22.3125 -1.421875 17.546875 -0.640625
# Q 12.796875 0.140625 7.71875 1.703125
# L 7.71875 11.625
# Q 12.109375 9.234375 16.796875 8.0625
# Q 21.484375 6.890625 26.703125 6.890625
# Q 35.15625 6.890625 40.078125 11.328125
# Q 45.015625 15.765625 45.015625 23.390625
# Q 45.015625 31 40.078125 35.4375
# Q 35.15625 39.890625 26.703125 39.890625
# Q 22.75 39.890625 18.8125 39.015625
# Q 14.890625 38.140625 10.796875 36.28125
# z
# " id="DejaVuSans-35"/>
#       </defs>
#       <g transform="translate(201.273543 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-35"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#pebc83bd87c)" d="M 382.004013 273.485354
# L 382.004013 2.834646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="382.004013" xlink:href="#mf9f654c1f0" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 100 -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#       </defs>
#       <g transform="translate(374.369013 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <path clip-path="url(#pebc83bd87c)" d="M 20.184646 265.825429
# L 392.542441 265.825429
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_8">
#       <defs>
#        <path d="M 0 0
# L -3.5 0
# " id="mc55fa8bd0f" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="20.184646" xlink:href="#mc55fa8bd0f" y="265.825429"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 0.0 -->
#       <defs>
#        <path d="M 10.6875 12.40625
# L 21 12.40625
# L 21 0
# L 10.6875 0
# z
# " id="DejaVuSans-2e"/>
#       </defs>
#       <g transform="translate(0.462146 268.864804)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-2e"/>
#        <use x="95.410156" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_9">
#       <path clip-path="url(#pebc83bd87c)" d="M 20.184646 137.862978
# L 392.542441 137.862978
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="20.184646" xlink:href="#mc55fa8bd0f" y="137.862978"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 0.5 -->
#       <g transform="translate(0.462146 140.902353)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-2e"/>
#        <use x="95.410156" xlink:href="#DejaVuSans-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_11">
#       <path clip-path="url(#pebc83bd87c)" d="M 20.184646 9.900528
# L 392.542441 9.900528
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="20.184646" xlink:href="#mc55fa8bd0f" y="9.900528"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 1.0 -->
#       <g transform="translate(0.462146 12.939903)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-2e"/>
#        <use x="95.410156" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="PolyCollection_1">
#     <path clip-path="url(#pebc83bd87c)" d="M 30.723074 226.371923
# L 30.723074 265.825429
# L 65.851168 265.825429
# L 100.979262 265.825429
# L 136.107356 265.825429
# L 171.235449 265.825429
# L 206.363543 265.825429
# L 241.491637 265.825429
# L 276.619731 265.825429
# L 311.747825 265.825429
# L 346.875919 265.825429
# L 382.004013 265.825429
# L 382.004013 33.517198
# L 382.004013 33.517198
# L 346.875919 80.499481
# L 311.747825 154.019921
# L 276.619731 101.404408
# L 241.491637 90.684157
# L 206.363543 218.073616
# L 171.235449 84.527852
# L 136.107356 68.42912
# L 100.979262 48.823382
# L 65.851168 261.260161
# L 30.723074 226.371923
# z
# " style="fill:#0d0d0d;fill-opacity:0.4;"/>
#    </g>
#    <g id="line2d_13">
#     <path clip-path="url(#pebc83bd87c)" d="M 30.723074 226.371923
# L 65.851168 261.260161
# L 100.979262 48.823382
# L 136.107356 68.42912
# L

# %% [markdown]
# ## Gráficas en 3D
#
# La siguiente gráfica se ve mejor en formato `HTML`, porque resulta interactiva y se puede rotar sobre los tres ejes.
#
# Como ejercicio, en su consola use:
#
# ```julia
# plotlyjs()  # Definimos motor
# ...
# ```

# %%
n      = 100
ts     = linspace(0, 8π, n)
x      = ts .* map(cos, ts)
y      = (0.1ts) .* map(sin, ts)
z      = 1:n

#plotlyjs()  # Use este motor para hacer la gráfica interactiva

plot(x, y, z,
zcolor = reverse(z),
m      = (10,0.8, :blues, stroke(0)),
leg    = false,
cbar   = true,w=5)


plot!(zeros(n),
zeros(n),
1:n,
w   = 10,
fmt = :svg)  # Opción para generar las notas
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 2.834646 285.165354
# L 389.302441 285.165354
# L 389.302441 2.834646
# L 2.834646 2.834646
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 54.066924 222.780218
# L 164.676029 153.559125
# L 162.834505 21.288978
# L 46.058217 83.482706
# " style="fill:#f2f2f2;opacity:0.5;stroke:#f2f2f2;stroke-linejoin:miter;"/>
#    </g>
#   </g>
#   <g id="pane3d_2">
#    <g id="patch_4">
#     <path d="M 164.676029 153.559125
# L 343.85238 192.258183
# L 351.348904 55.999483
# L 162.834505 21.288978
# " style="fill:#e6e6e6;opacity:0.5;stroke:#e6e6e6;stroke-linejoin:miter;"/>
#    </g>
#   </g>
#   <g id="pane3d_3">
#    <g id="patch_5">
#     <path d="M 54.066924 222.780218
# L 242.584656 267.851576
# L 343.85238 192.258183
# L 164.676029 153.559125
# " style="fill:#ececec;opacity:0.5;stroke:#ececec;stroke-linejoin:miter;"/>
#    </g>
#   </g>
#   <g id="axis3d_1">
#    <g id="line2d_1">
#     <path d="M 54.066924 222.780218
# L 242.584656 267.851576
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#    </g>
#    <g id="Line3DCollection_1">
#     <path d="M 69.496603 226.46919
# L 179.386362 156.736308
# L 178.280571 24.133009
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#     <path d="M 104.680868 234.881144
# L 212.900075 163.974702
# L 213.491085 30.616199
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#     <path d="M 140.482393 243.440675
# L 246.95867 171.330782
# L 249.303461 37.210209
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#     <path d="M 176.917566 252.1517
# L 281.575545 178.807441
# L 285.733265 43.917903
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#     <path d="M 214.00336 261.018278
# L 316.764539 186.407668
# L 322.796603 50.742247
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#    </g>
#    <g id="xtick_1">
#     <g id="line2d_2">
#      <path clip-path="url(#p3cf74b9c47)" d="M 201.291081 140.18472
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#     </g>
#     <g id="line2d_3">
#      <path d="M 70.443426 225.868363
# L 67.599423 227.673086
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#     </g>
#     <g id="text_1">
#      <!-- -20 -->
#      <defs>
#       <path d="M 4.890625 31.390625
# L 31.203125 31.390625
# L 31.203125 23.390625
# L 4.890625 23.390625
# z
# " id="DejaVuSans-2d"/>
#       <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#       <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#      </defs>
#      <g transform="translate(55.581979 246.277392)scale(0.08 -0.08)">
#       <use xlink:href="#DejaVuSans-2d"/>
#       <use x="36.083984" xlink:href="#DejaVuSans-32"/>
#       <use x="99.707031" xlink:href="#DejaVuSans-30"/>
#      </g>
#     </g>
#    </g>
#    <g id="xtick_2">
#     <g id="line2d_4">
#      <path clip-path="url(#p3cf74b9c47)" d="M 201.291081 140.18472
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#     </g>
#     <g id="line2d_5">
#      <path d="M 105.613876 234.269826
# L 102.811337 236.106081
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#     </g>
#     <g id="text_2">
#      <!-- -10 -->
#      <defs>
#       <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#      </defs>
#      <g transform="translate(90.762732 254.823471)scale(0.08 -0.08)">
#       <use xlink:href="#DejaVuSans-2d"/>
#       <use x="36.083984" xlink:href="#DejaVuSans-31"/>
#       <use x="99.707031" xlink:href="#DejaVuSans-30"/>
#      </g>
#     </g>
#    </g>
#    <g id="xtick_3">
#     <g id="line2d_6">
#      <path clip-path="url(#p3cf74b9c47)" d="M 201.291081 140.18472
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#     </g>
#     <g id="line2d_7">
#      <path d="M 141.400955 242.818589
# L 138.64178 244.68721
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#     </g>
#     <g id="text_3">
#      <!-- 0 -->
#      <g transform="translate(130.549885 263.51974)scale(0.08 -0.08)">
#       <use xlink:href="#DejaVuSans-30"/>
#      </g>
#     </g>
#    </g>
#    <g id="xtick_4">
#     <g id="line2d_8">
#      <path clip-path="url(#p3cf74b9c47)" d="M 201.291081 140.18472
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#     </g>
#     <g id="line2d_9">
#      <path d="M 177.821022 251.518559
# L 175.107192 253.42041
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#     </g>
#     <g id="text_4">
#      <!-- 10 -->
#      <g transform="translate(164.438631 272.370195)scale(0.08 -0.08)">
#       <use xlink:href="#DejaVuSans-31"/>
#       <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#      </g>
#     </g>
#    </g>
#    <g id="xtick_5">
#     <g id="line2d_10">
#      <path clip-path="url(#p3cf74b9c47)" d="M 201.291081 140.18472
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#     </g>
#     <g id="line2d_11">
#      <path d="M 214.891022 260.373784
# L 212.224604 262.309759
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#     </g>
#     <g id="text_5">
#      <!-- 20 -->
#      <g transform="translate(201.524125 281.378972)scale(0.08 -0.08)">
#       <use xlink:href="#DejaVuSans-32"/>
#       <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#      </g>
#     </g>
#    </g>
#   </g>
#   <g id="axis3d_2">
#    <g id="line2d_12">
#     <path d="M 343.85238 192.258183
# L 242.584656 267.851576
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-width:0.8;"/>
#    </g>
#    <g id="Line3DCollection_2">
#     <path d="M 61.194375 75.42136
# L 68.355119 213.838418
# L 255.704408 258.058065
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#     <path d="M 86.304548 62.047966
# L 92.090401 198.984467
# L 277.473555 241.808033
# " style="fill:none;stroke:#b0b0b0;stroke-width:0.8;"/>
#     <path d="M 1

# %% [markdown]
# ## Contornos

# %%
# plotly()      # ¡Pruebe diferentes motores!

x      = 1:0.5:20
y      = 1:0.5:10

f(x,y) = begin 
            (3x + y ^ 2) * abs(sin(x) + cos(y))
         end

X      = repmat(x', length(y), 1)
Y      = repmat(y, 1, length(x))
Z      = map(f, X, Y)


p1     = contour(x, y, f, fill=true)
p2     = contour(x, y, Z)


plot(p1, p2, 
fmt    = :svg)  # Opción para generar las notas)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 25.314646 273.485354
# L 170.692441 273.485354
# L 170.692441 3.194646
# L 25.314646 3.194646
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p2cb5da2805)" d="M 55.920497 273.485354
# L 55.920497 3.194646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="m4e29bdc6a2" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="55.920497" xlink:href="#m4e29bdc6a2" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 5 -->
#       <defs>
#        <path d="M 10.796875 72.90625
# L 49.515625 72.90625
# L 49.515625 64.59375
# L 19.828125 64.59375
# L 19.828125 46.734375
# Q 21.96875 47.46875 24.109375 47.828125
# Q 26.265625 48.1875 28.421875 48.1875
# Q 40.625 48.1875 47.75 41.5
# Q 54.890625 34.8125 54.890625 23.390625
# Q 54.890625 11.625 47.5625 5.09375
# Q 40.234375 -1.421875 26.90625 -1.421875
# Q 22.3125 -1.421875 17.546875 -0.640625
# Q 12.796875 0.140625 7.71875 1.703125
# L 7.71875 11.625
# Q 12.109375 9.234375 16.796875 8.0625
# Q 21.484375 6.890625 26.703125 6.890625
# Q 35.15625 6.890625 40.078125 11.328125
# Q 45.015625 15.765625 45.015625 23.390625
# Q 45.015625 31 40.078125 35.4375
# Q 35.15625 39.890625 26.703125 39.890625
# Q 22.75 39.890625 18.8125 39.015625
# Q 14.890625 38.140625 10.796875 36.28125
# z
# " id="DejaVuSans-35"/>
#       </defs>
#       <g transform="translate(53.375497 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p2cb5da2805)" d="M 94.177812 273.485354
# L 94.177812 3.194646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="94.177812" xlink:href="#m4e29bdc6a2" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 10 -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#       </defs>
#       <g transform="translate(89.087812 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p2cb5da2805)" d="M 132.435126 273.485354
# L 132.435126 3.194646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="132.435126" xlink:href="#m4e29bdc6a2" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 15 -->
#       <g transform="translate(127.345126 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p2cb5da2805)" d="M 170.692441 273.485354
# L 170.692441 3.194646
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="170.692441" xlink:href="#m4e29bdc6a2" y="273.485354"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 20 -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#       </defs>
#       <g transform="translate(165.602441 286.564104)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_9">
#       <path clip-path="url(#p2cb5da2805)" d="M 25.314646 228.436903
# L 170.692441 228.436903
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_10">
#       <defs>
#        <path d="M 0 0
# L -3.5 0
# " id="m7991d1ce5c" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="25.314646" xlink:href="#m7991d1ce5c" y="228.436903"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 2.5 -->
#       <defs>
#        <path d="M 10.6875 12.40625
# L 21 12.40625
# L 21 0
# L 10.6875 0
# z
# " id="DejaVuSans-2e"/>
#       </defs>
#       <g transform="translate(5.592146 231.476278)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-2e"/>
#        <use x="95.410156" xlink:href="#DejaVuSans-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_11">
#       <path clip-path="url(#p2cb5da2805)" d="M 25.314646 153.35615
# L 170.692441 153.35615
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="25.314646" xlink:href="#m7991d1ce5c" y="153.35615"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 5.0 -->
#       <g transform="translate(5.592146 156.395525)scale(0.08 -0.08)">
#        <use xlink:href="#DejaVuSans-35"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-2e"/>
#        <use x="95.410156" xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_13">
#       <path clip-path="url(#p2cb5da2805)" d="M 25.314646 78.275398
# L 170.692441 78.275398
# " style="fill:none;stroke:#000000;stroke-dasharray:0.8,1.32;stroke-dashoffset:0;strok

# %% [markdown]
# # Para saber más:
#
# ## Conceptos básicos y tips
#
# https://juliaplots.github.io/basics/
#
# ## Ventajas y desventajas de los motores
#
# https://juliaplots.github.io/backends/
#
# ## Formatos de salida
#
# https://juliaplots.github.io/output/

# %% [markdown]
# # Reproducibilidad
#
# Esta libreta se modificó para:
# * Hacer más eficiente la instalación de librerías, vía la función local *it()*.

# %%
versioninfo()
# Out:
# Julia Version 0.6.0-rc2.0
# Commit 68e911be53* (2017-05-18 02:31 UTC)
# Platform Info:
#   OS: Linux (x86_64-solus-linux)
#   CPU: Intel(R) Core(TM) i5-4590 CPU @ 3.30GHz
#   WORD_SIZE: 64
#   BLAS: libopenblas (NO_AFFINITY CORE2)
#   LAPACK: libopenblas
#   LIBM: libopenlibm
#   LLVM: libLLVM-4.0.0 (ORCJIT, haswell)

# %%
Dates.today()
# Out:
# 2017-06-21
