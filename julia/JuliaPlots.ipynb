# %% [markdown]
# <div style='background-image: url("../../share/images/header.svg") ; padding: 0px ; background-size: cover ; border-radius: 5px ; height: 250px'>
#     <div style="float: right ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.7) ; width: 50% ; height: 150px">
#         <div style="position: relative ; top: 50% ; transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.8) ; line-height: 100%">Plots en Julia</div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.5)">Ulises M. Alvarez</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# La librería, `Plots`, es una interface de visualización y una caja de herramientas. Nos permite usar el poder de muchas de las librerías de gráficos de Julia, *i.e. motores*, usando una sintaxis única.
#
# Como principales ventajas podemos destacar:
#
# * Dialecto de gráficos universal. No importa el motor de gráficos que estemos usando, `PyPlot, Gadfly, Plotly, PGFPlots,` etc, podemos usar un sólo dialecto para construir las gráficas.
#
# * Se puede cambiar el motor de gráficos con un sólo comando y no es necesario reescribir el código.
#
# * Es muy sencillo agregar capas, --anotaciones, leyendas, incluso gráficos adicionales superpuestos--, a un gráfico.

# %% [markdown]
# > **Para saber más:**
# > https://juliaplots.github.io/

# %% [markdown]
# # Prerrequisitos de sistema operativo
#
# En sistemas *Linux*, se necesita instalar el software:
# * libgtk-3-dev
# * libwandio-devel

# %% [markdown]
# # Instalación de librería
#
# ## Cero: Inicializar entorno de Julia

# %%
ENV["PYTHON"] = ""  # Declaramos la variable PYTHON nula, para reproducibilidad
Pkg.update()
# Out:
# INFO: Updating METADATA...
# INFO: Computing changes...
# INFO: No packages to install, update or remove

# %% [markdown]
# ## Instalación de la librería
#
# Una vez inicializado el entorno, procedemos a instalar la librería:
#
# **VER:**
# * https://docs.julialang.org/en/release-0.5/manual/packages/

# %%
if !haskey(Pkg.installed(), "Plots")
    Pkg.add("Plots")
end

# %% [markdown]
# ## Instalación de Motores
#
# Ahora, instalaremos los motores recomendados:
#
# > **URL:** https://juliaplots.github.io/install/

# %%
if !haskey(Pkg.installed(), "PlotlyJS")
    Pkg.add("PlotlyJS")
end

# %%
if !haskey(Pkg.installed(), "PyPlot")
    Pkg.add("PyPlot")
end

# %%
if !haskey(Pkg.installed(), "GR")
    Pkg.add("GR")
end

# %%
if !haskey(Pkg.installed(), "UnicodePlots")
    Pkg.add("UnicodePlots")
end

# %%
if !haskey(Pkg.installed(), "PGFPlots")
    Pkg.add("PGFPlots")
end

# %% [markdown]
# ## Extensiones
#
# También instalaremos las extensiones recomendadas:

# %%
if !haskey(Pkg.installed(), "StatPlots")
    Pkg.add("StatPlots")
end

# %%
if !haskey(Pkg.installed(), "PlotRecipes")
    Pkg.add("PlotRecipes")
end

# %% [markdown]
# ## Auxiliares
#
# Para poder desplegar los gráficos generados con el motor, `PlotlyJS`, es importante ejecutar:

# %%
if !haskey(Pkg.installed(), "PlotRecipes")
    Pkg.add("Blink")
end

# %%
using Blink

# %% [markdown]
# ** El siguiente comando sólo debe ejecutarse una vez:**

# %%
# Blink.AtomShell.install()  # Ejecutar sólo una vez

# %% [markdown]
# **Referencia:** http://spencerlyon.com/PlotlyJS.jl/

# %%
if !haskey(Pkg.installed(), "Rsvg")
    Pkg.add("Rsvg")
end

# %%
using Rsvg

# %% [markdown]
# **Nota:**
# > La instalación de librerías es un proceso que requiere de 10 a 20 minutos. El resultado variará de acuerdo a su sistema operativo y la velocidad de su conexión a Internet.

# %% [markdown]
# # Uso de `Plots`
#
# Una vez instaladas la librerías, podemos proceder a usar `Plots` con el motor de nuesta preferencia. Es importante señalar que:
#
# * Para generar estas notas usamos el motor, `GR`.
# * Para sesiones o documentos interactivos, *i.e. html,* se recomienda el motor `plotly()`.
# * Para poder exportar desde `Jupyter` o `IJulia`, es necesario especificar el formato de salida. Les recomendamos `SVG` o `PNG`. Ejemplo:
#
# ```julia
# plot(rand(10), fmt = :svg)
#
# ```
#
# > **URL:** https://juliaplots.github.io/output/

# %%
using Plots  # Cargamos librería
gr()         # Definimos motor
# Out:
# Plots.GRBackend()

# %% [markdown]
# ## Gráfica simple de líneas
#
# Generaremos una gráfica de líneas. Usaremo el motor `PGFPlots` y `SVG` como formato de salida:

# %%
#plotly()                    # ¡Pruebe diferentes motores!

plot(Plots.fakedata(50, 5),  # las abcisas y las ordenadas, respectivamente
w   = 2,                     # Ancho de las líneas
fmt = :svg)                  # Opción para generar las notas
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 21.7148,384.952 596.063,384.952 596.063,3.93701 21.7148,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="21" y="3" width="575" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   127.207,379.237 127.207,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   244.421,379.237 244.421,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   361.635,379.237 361.635,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   478.849,379.237 478.849,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,379.237 596.063,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.33,377.11 587.448,377.11
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.33,230.743 587.448,230.743
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.33,84.3772 587.448,84.3772
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   127.207,384.952 127.207,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   244.421,384.952 244.421,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   361.635,384.952 361.635,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   478.849,384.952 478.849,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,384.952 21.7148,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,377.11 30.33,377.11
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,230.743 30.33,230.743
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,84.3772 30.33,84.3772
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 127.207, 396.952)" x="127.207" y="396.952">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 244.421, 396.952)" x="244.421" y="396.952">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 361.635, 396.952)" x="361.635" y="396.952">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 478.849, 396.952)" x="478.849" y="396.952">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 396.952)" x="596.063" y="396.952">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 20.5148, 381.61)" x="20.5148" y="381.61">-5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 20.5148, 235.243)" x="20.5148" y="235.243">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 20.5148, 88.8772)" x="20.5148" y="88.8772">5</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:1.6; stroke-opacity:1; fill:none" points="
#   21.7148,230.743 33.4362,215.391 45.1576,214.034 56.879,260.777 68.6004,255.933 80.3217,188.233 92.0431,217.586 103.765,239.93 115.486,216.084 127.207,230.916
#   138.929,194.145 150.65,196.771 162.371,187.647 174.093,133.567 185.814,138.632 197.536,108.545 209.257,114.567 220.978,149.895 232.7,146.402 244.421,126.7
#   256.143,146.146 267.864,169.918 279.585,165.028 291.307,178.719 303.028,136.571 314.75,149.726 326.471,92.2721 338.192,97.5482 349.914,80.2488 361.635,98.5624
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 44.9091,65.9768 92.594,357.462 140.279,183.493 187.964,46.7574 235.648,254.729 283.333,117.481 331.018,350.836 378.703,250.645 426.388,158.607 474.073,355.723
#   521.758,25.8692 521.758,374.168 474.073,374.168 426.388,374.168 378.703,374.168 331.018,374.168 283.333,374.168 235.648,374.168 187.964,374.168 140.279,374.168
#   92.594,374.168 44.9091,374.168
#   " fill="#7f7f7f" fill-opacity="0.4"/>
# <polyline clip-path="url(#clip02)" style="stroke:#7f7f7f; stroke-width:2.4; stroke-opacity:0.4; fill:none" points="
#   44.9091,65.9768 92.594,357.462 140.279,183.493 187.964,46.7574 235.648,254.729 283.333,117.481 331.018,350.836 378.703,250.645 426.388,158.607 474.073,355.723
#   521.758,25.8692
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 44.9091,151.044 92.594,264.578 140.279,166.892 187.964,270.522 235.648,372.247 283.333,250.879 331.018,139.1 378.703,176.265 426.388,301.742 474.073,159.627
#   521.758,79.5694 521.758,374.168 474.073,374.168 426.388,374.168 378.703,374.168 331.018,374.168 283.333,374.168 235.648,374.168 187.964,374.168 140.279,374.168
#   92.594,374.168 44.9091,374.168
#   " fill="#444444" fill-opacity="0.4"/>
# <polyline clip-path="url(#clip02)" style="stroke:#444444; stroke-width:2.4; stroke-opacity:0.4; fill:none" points="
#   44.9091,151.044 92.594,264.578 140.279,166.892 187.964,270.522 235.648,372.247 283.333,250.879 331.018,139.1 378.703,176.265 426.388,301.742 474.073,159.627
#   521.758,79.5694
#   "/>
# <circle clip-path="url(#clip02)" style="fill:#008100; stroke:none; fill-opacity:0.8" cx="49.6776" cy="309.41" r="5"/>
# <circle clip-path="url(#clip02)" style="fill:#de7700; stroke:none; fill-opacity:0.8" cx="49.6776" cy="309.41" r="5"/>
# <circle clip-path="url(#clip02)" style="fill:#008100; stroke:none; fill-opacity:0.8" cx="54.4461" cy="183.104" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#fff4c5; stroke:none; fill-opacity:0.8" cx="54.4461" cy="183.104" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#008100; stroke:none; fil

# %% [markdown]
# ## Gráficas en 3D
#
# La siguiente gráfica se ve mejor en formato `HTML`, porque resulta interactiva y se puede rotar sobre los tres ejes.
#
# Como ejercicio, en su consola use:
#
# ```julia
# plotlyjs()  # Definimos motor
# ...
# ```

# %%
n      = 100
ts     = linspace(0, 8π, n)
x      = ts .* map(cos, ts)
y      = (0.1ts) .* map(sin, ts)
z      = 1:n

#plotlyjs()  # Use este motor para hacer la gráfica interactiva

plot(x, y, z,
zcolor = reverse(z),
m      = (10,0.8, :blues, stroke(0)),
leg    = false,
cbar   = true,w=5)


plot!(zeros(n),
zeros(n),
1:n,
w   = 10,
fmt = :svg)  # Opción para generar las notas
# Out:
# WARNING: blues is found in more than one library: misc, colorcet. Choosing misc
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 21.7148,384.952 596.063,384.952 596.063,3.93701 21.7148,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="21" y="3" width="515" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,279.187 256.389,128.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,128.972 536.063,234.737
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,263.558 256.389,113.342
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,113.342 536.063,219.107
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,247.928 256.389,97.7131
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,97.7131 536.063,203.478
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,232.299 256.389,82.0838
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,82.0838 536.063,187.849
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,216.67 256.389,66.4544
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,66.4544 536.063,172.219
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,201.04 256.389,50.8251
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,50.8251 536.063,156.59
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,185.411 256.389,35.1957
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,35.1957 536.063,140.961
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,169.782 256.389,19.5664
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,19.5664 536.063,125.331
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,154.152 256.389,3.93701
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   256.389,3.93701 536.063,109.702
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   40.7526,286.387 275.427,136.171
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   275.427,136.171 275.427,11.1366
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   68.7501,296.975 303.424,146.759
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   303.424,146.759 303.424,21.7244
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   96.7476,307.562 331.422,157.347
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   331.422,157.347 331.422,32.3123
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   124.745,318.15 359.419,167.935
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   359.419,167.935 359.419,42.9002
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   152.743,328.738 387.417,178.523
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   387.417,178.523 387.417,53.488
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   180.74,339.326 415.414,189.111
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   415.414,189.111 415.414,64.0759
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   208.738,349.914 443.412,199.699
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   443.412,199.699 443.412,74.6638
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   236.735,360.502 471.409,210.286
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   471.409,210.286 471.409,85.2516
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   264.733,371.09 499.407,220.874
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   499.407,220.874 499.407,95.8395
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   292.73,381.677 527.404,231.462
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   527.404,231.462 527.404,106.427
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   46.4098,263.38 326.084,369.145
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   46.4098,263.38 46.4098,138.345
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   71.6041,247.253 351.278,353.018
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   71.6041,247.253 71.6041,122.218
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   96.7984,231.126 376.472,336.891
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   96.7984,231.126 96.7984,106.091
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   121.993,214.999 401.667,320.764
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   121.993,214.999 121.993,89.9642
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   147.187,198.872 426.861,304.63

# %% [markdown]
# ## Contornos

# %%
# plotly()      # ¡Pruebe diferentes motores!

x      = 1:0.5:20
y      = 1:0.5:10

f(x,y) = begin 
            (3x + y ^ 2) * abs(sin(x) + cos(y))
         end

X      = repmat(x', length(y), 1)
Y      = repmat(y, 1, length(x))
Z      = map(f, X, Y)


p1     = contour(x, y, f, fill=true)
p2     = contour(x, y, Z)


plot(p1, p2, 
fmt    = :svg)  # Opción para generar las notas)
# Out:
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  [2] Array(::Type{Plots.Plot}, ::Int64) at ./deprecated.jl:51
#  [3] #plot#274(::Array{Any,1}, ::Function, ::Plots.Plot{Plots.GRBackend}, ::Plots.Plot{Plots.GRBackend}, ::Vararg{Plots.Plot{Plots.GRBackend},N} where N) at /home/uma/.julia/v0.6/Plots/src/plot.jl:63
#  [4] (::Plots.#kw##plot)(::Array{Any,1}, ::Plots.#plot, ::Plots.Plot{Plots.GRBackend}, ::Plots.Plot{Plots.GRBackend}, ::Vararg{Plots.Plot{Plots.GRBackend},N} where N) at ./<missing>:0
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/uma/.julia/v0.6/IJulia/src/execute_request.jl:156
#  [6] eventloop(::ZMQ.Socket) at /home/uma/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [7] (::IJulia.##9#12)() at ./task.jl:335
# while loading In[36], in expression starting on line 19
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 296.063,384.952 296.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="197" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.8758,379.237 80.8758,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#
# nxA1QOM12wPzYf8RmAAigEAgKBgAASDy16RgEhDpfLD65ypA8vD7Uzhjifne+Bz7brXvJczvBvlr
# AiuDiUFoYAJEWwYcv09irKDzuG3sRDb++t15TaRgUhCLjZfVgo6sADfEG5UZYPbn5n9TX/uHs4+d
# JT+Tc+zqc17mgLBesc8Byj383vH7fY/XTAwWBhP5PJfH6f7Gtdp4fWK4lccMDBN7YI7mz5Q2qP+t
# cvP5OX2Pry0u64Hj2Udp/29gYoj6T4kBfVmIl7xkEa4a/qwhVCXTNlSnBiVq9uxaxj6IwUquf1LZ
# lS9S/BJCNK/FXoeWaMt4Q+uFKMZ8rav1sPFzakhCA+ucwakhQzspGD/f+LlYI4auc5AWotkcENuF
# FlGMTNWo81BlRQaUyGA+3FJhau5874+4FuK2hYUklokQgPlMZS1MLHP3eRtOCyEWhuoAEZ8Wxv3k
# xKTWyfmlpMISu/n3Ex/Xx76gSdvy+4ROClvV8Xz/Zbmp5pKYC+Oj6yMyuPSDFwYzEPfF4eUdbIAm
# XLMNEvCNsGlDoy1zkQwytDl+BQSWS2a5TN1/N+8/EaPRhoYdDQ0txk9Yvnu9bp1w12EhCgRKyMQl
# l6lCKN79bxkU74/PPc1zfmVsBACNgEaETRoGFYVQ3r6tu+SsJSX/+Iyx88MQ2qItODq05PQnbIEu
# i+JnEEZsjtAOdFrEtjEebXZVmZviJPE+G3cdu2thKtrRMf0PFeWiZnwREJcbz48/O76zeoXL+P36
# iVqZh3XMj3yriibIt8K0QCfLWHD9vLCv89e+SnJgU8ms36u5BqZfV69/opz6cS95yUtwYpnucLSO
# O7igEGcmfmEJZumkFRbNULRWaq8EN8YyKBikz8etKqA76xj+g0GG5G2CyaBpmcyfck39yDIm48Lz
# 8b1jL/cs2Dk+QSaa1qn6EGkX3d8LuLuOXx7c99WCpu8UlhFUrPADRMAKcmbRxkzrWOnr1pRShVic
# 5s++R06Mo57uPYwFLP+dZTtvgtggtvAfQ4kqYXIq9VidasbP61BWmQuxOlR3rqCPoy0L33yogqtd
# Fkc8FwSDlQ0q0jOXoziVsTh+TOhQJJUC5j2YdOj0dvi0GepGON/3M7EAVOe0QiZNyATE3P+w+1/9
# B5INcCr27u+cvj4rhfOmaETYQNh0w0AHkSnF6ke+INNLXlJk+2hPfE2wajJMdZf9MkzTpNs0GaZH
# V2JX3Pyae/7cqMaxMk3L57fy2mFT

# %% [markdown]
# # Para saber más:
#
# ## Conceptos básicos y tips
#
# https://juliaplots.github.io/basics/
#
# ## Ventajas y desventajas de los motores
#
# https://juliaplots.github.io/backends/
#
# ## Formatos de salida
#
# https://juliaplots.github.io/output/

# %% [markdown]
# # Actualización a julia v.0.5 y v.0.6
#
# Esta libreta se modificó el 2017-06-07 para:
# * Hacer más eficiente la instalación de librerías. Ahora, si la librería ya está en la biblioteca del usuario, no se descarga.
# * Se evaluó el código en:

# %%
VERSION
# Out:
# v"0.6.0-rc2.0"
